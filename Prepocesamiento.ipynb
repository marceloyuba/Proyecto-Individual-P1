# %% [markdown]
# Importo las librerias que son necesarias para Generar el ETL

# %%
import pandas as pd
import ast
import json
import parquet

# %% [markdown]
# Leo el JSON output_steam_games

# %%
# Importar el Data set
dataset = pd.read_json('output_steam_games.json', lines=True)

# %% [markdown]
# Leo el dataframe para ver que corrio bien

# %%
dataset
# Out:
#               publisher                                 genres  \
# 0                  None                                   None
# 1                  None                                   None
# 2                  None                                   None
# 3                  None                                   None
# 4                  None                                   None
# ...                 ...                                    ...
# 120440  Ghost_RUS Games  [Casual, Indie, Simulation, Strategy]
# 120441           Sacada              [Casual, Indie, Strategy]
# 120442     Laush Studio            [Indie, Racing, Simulation]
# 120443         SIXNAILS                        [Casual, Indie]
# 120444             None                                   None
#
#                         app_name                     title  \
# 0                           None                      None
# 1                           None                      None
# 2                           None                      None
# 3                           None                      None
# 4                           None                      None
# ...                          ...                       ...
# 120440            Colony On Mars            Colony On Mars
# 120441  LOGistICAL: South Africa  LOGistICAL: South Africa
# 120442             Russian Roads             Russian Roads
# 120443       EXIT 2 - Directions       EXIT 2 - Directions
# 120444               Maze Run VR                      None
#
#                                                       url release_date  \
# 0                                                    None         None
# 1                                                    None         None
# 2                                                    None         None
# 3                                                    None         None
# 4                                                    None         None
# ...                                                   ...          ...
# 120440  http://store.steampowered.com/app/773640/Colon...   2018-01-04
# 120441  http://store.steampowered.com/app/733530/LOGis...   2018-01-04
# 120442  http://store.steampowered.com/app/610660/Russi...   2018-01-04
# 120443  http://store.steampowered.com/app/658870/EXIT_...   2017-09-02
# 120444  http://store.steampowered.com/app/681550/Maze_...         None
#
#                                                      tags  \
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 120440              [Strategy, Indie, Casual, Simulation]
# 120441                          [Strategy, Indie, Casual]
# 120442                        [Indie, Simulation, Racing]
# 120443  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...
# 120444  [Early Access, Adventure, Indie, Action, Simul...
#
#                                               reviews_url  \
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 120440  http://steamcommunity.com/app/773640/reviews/?...
# 120441  http://steamcommunity.com/app/733530/reviews/?...
# 120442  http://steamcommunity.com/app/610660/reviews/?...
# 120443  http://steamcommunity.com/app/658870/reviews/?...
# 120444  http://steamcommunity.com/app/681550/reviews/?...
#
#                                                     specs price  early_access  \
# 0                                                    None  None           NaN
# 1                                                    None  None           NaN
# 2                                                    None  None           NaN
# 3                                                    None  None           NaN
# 4                                                    None  None           NaN
# ...                                                   ...   ...           ...
# 120440                [Single-player, Steam Achievements]  1.99           0.0
# 120441  [Single-player, Steam Achievements, Steam Clou...  4.99           0.0
# 120442  [Single-player, Steam Achievements, Steam Trad...  1.99           0.0
# 120443   [Single-player, Steam Achievements, Steam Cloud]  4.99           0.0
# 120444  [Single-player, Stats, Steam Leaderboards, HTC...  4.99           1.0
#
#               id                 developer
# 0            NaN                      None
# 1            NaN                      None
# 2            NaN                      None
# 3            NaN                      None
# 4            NaN                      None
# ...          ...                       ...
# 120440  773640.0        Nikita "Ghost_RUS"
# 120441  733530.0                    Sacada
# 120442  610660.0  Laush Dmitriy Sergeevich
# 120443  658870.0             xropi,stev3ns
# 120444  681550.0                      None
#
# [120445 rows x 13 columns]

# %% [markdown]
# Veo la forma del dataset con Shape

# %%
dataset.shape
# Out:
# (120445, 13)

# %% [markdown]
# Analizo si hay ID repetidas

# %%
call_id_counts = dataset['id'].value_counts()
call_id_counts
# Out:
# id
# 612880.0    2
# 761140.0    1
# 530200.0    1
# 518690.0    1
# 513460.0    1
#            ..
# 676060.0    1
# 494160.0    1
# 215280.0    1
# 667090.0    1
# 681550.0    1
# Name: count, Length: 32132, dtype: int64

# %% [markdown]
# Verifico cuantas se repiten

# %%
id_mas_de_una_vez = call_id_counts[call_id_counts > 1].index.tolist()

print(id_mas_de_una_vez)
# Out:
# [612880.0]

# %% [markdown]
# Busco las filas que tienen los ID repetidos para su analisis

# %%
fila_resultado = dataset[dataset['id'] == 612880.0]
fila_resultado
# Out:
#                  publisher    genres                          app_name  \
# 102204  Bethesda Softworks  [Action]  Wolfenstein II: The New Colossus
# 102883  Bethesda Softworks  [Action]  Wolfenstein II: The New Colossus
#
#                                    title  \
# 102204  Wolfenstein II: The New Colossus
# 102883  Wolfenstein II: The New Colossus
#
#                                                       url release_date  \
# 102204          http://store.steampowered.com/app/612880/   2017-10-26
# 102883  http://store.steampowered.com/app/612880/Wolfe...   2017-10-26
#
#                                                      tags  \
# 102204  [Action, FPS, Gore, Violent, Alternate History...
# 102883  [Action, FPS, Gore, Violent, Alternate History...
#
#                                               reviews_url  \
# 102204  http://steamcommunity.com/app/612880/reviews/?...
# 102883  http://steamcommunity.com/app/612880/reviews/?...
#
#                                                     specs  price  \
# 102204  [Single-player, Steam Achievements, Full contr...  59.99
# 102883  [Single-player, Steam Achievements, Full contr...  59.99
#
#         early_access        id      developer
# 102204           0.0  612880.0  Machine Games
# 102883           0.0  612880.0  Machine Games

# %% [markdown]
# Al ver que son el mismo elemento repetido, procedo con la eliminacion de una de ellas

# %%
dataset = dataset.drop(102883)

# %% [markdown]
# Ya se encuentra sin repetidos el dataset

# %%
fila_resultado = dataset[dataset['id'] == 612880.0]
fila_resultado
# Out:
#                  publisher    genres                          app_name  \
# 102204  Bethesda Softworks  [Action]  Wolfenstein II: The New Colossus
#
#                                    title  \
# 102204  Wolfenstein II: The New Colossus
#
#                                               url release_date  \
# 102204  http://store.steampowered.com/app/612880/   2017-10-26
#
#                                                      tags  \
# 102204  [Action, FPS, Gore, Violent, Alternate History...
#
#                                               reviews_url  \
# 102204  http://steamcommunity.com/app/612880/reviews/?...
#
#                                                     specs  price  \
# 102204  [Single-player, Steam Achievements, Full contr...  59.99
#
#         early_access        id      developer
# 102204           0.0  612880.0  Machine Games

# %% [markdown]
# Ahora procedo a eliminar los NAN de las primeras filas(obtuve el resultado viendo hasta donde llegaban estas filas vacias en el CSV)

# %%
dataset = dataset.dropna()

# %%
dataset = dataset.drop(range(0, 88384))

# %%
dataset
# Out:
#                   publisher  \
# 88310             Kotoshiro
# 88311      Making Fun, Inc.
# 88312          Poolians.com
# 88313                  彼岸领域
# 88315   Trickjump Games Ltd
# ...                     ...
# 120439      Bidoniera Games
# 120440      Ghost_RUS Games
# 120441               Sacada
# 120442         Laush Studio
# 120443             SIXNAILS
#
#                                                    genres  \
# 88310       [Action, Casual, Indie, Simulation, Strategy]
# 88311                [Free to Play, Indie, RPG, Strategy]
# 88312   [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                         [Action, Adventure, Casual]
# 88315                     [Action, Adventure, Simulation]
# ...                                                   ...
# 120439                 [Action, Adventure, Casual, Indie]
# 120440              [Casual, Indie, Simulation, Strategy]
# 120441                          [Casual, Indie, Strategy]
# 120442                        [Indie, Racing, Simulation]
# 120443                                    [Casual, Indie]
#
#                         app_name                     title  \
# 88310        Lost Summoner Kitty       Lost Summoner Kitty
# 88311                  Ironbound                 Ironbound
# 88312    Real Pool 3D - Poolians   Real Pool 3D - Poolians
# 88313                    弹炸人2222                   弹炸人2222
# 88315      Battle Royale Trainer     Battle Royale Trainer
# ...                          ...                       ...
# 120439              Kebab it Up!              Kebab it Up!
# 120440            Colony On Mars            Colony On Mars
# 120441  LOGistICAL: South Africa  LOGistICAL: South Africa
# 120442             Russian Roads             Russian Roads
# 120443       EXIT 2 - Directions       EXIT 2 - Directions
#
#                                                       url release_date  \
# 88310   http://store.steampowered.com/app/761140/Lost_...   2018-01-04
# 88311   http://store.steampowered.com/app/643980/Ironb...   2018-01-04
# 88312   http://store.steampowered.com/app/670290/Real_...   2017-07-24
# 88313      http://store.steampowered.com/app/767400/2222/   2017-12-07
# 88315   http://store.steampowered.com/app/772540/Battl...   2018-01-04
# ...                                                   ...          ...
# 120439  http://store.steampowered.com/app/745400/Kebab...   2018-01-04
# 120440  http://store.steampowered.com/app/773640/Colon...   2018-01-04
# 120441  http://store.steampowered.com/app/733530/LOGis...   2018-01-04
# 120442  http://store.steampowered.com/app/610660/Russi...   2018-01-04
# 120443  http://store.steampowered.com/app/658870/EXIT_...   2017-09-02
#
#                                                      tags  \
# 88310       [Strategy, Action, Indie, Casual, Simulation]
# 88311   [Free to Play, Strategy, Indie, RPG, Card Game...
# 88312   [Free to Play, Simulation, Sports, Casual, Ind...
# 88313                         [Action, Adventure, Casual]
# 88315   [Action, Adventure, Simulation, FPS, Shooter, ...
# ...                                                   ...
# 120439        [Action, Indie, Casual, Violent, Adventure]
# 120440              [Strategy, Indie, Casual, Simulation]
# 120441                          [Strategy, Indie, Casual]
# 120442                        [Indie, Simulation, Racing]
# 120443  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...
#
#                                               reviews_url  \
# 88310   http://steamcommunity.com/app/761140/reviews/?...
# 88311   http://steamcommunity.com/app/643980/reviews/?...
# 88312   http://steamcommunity.com/app/670290/reviews/?...
# 88313   http://steamcommunity.com/app/767400/reviews/?...
# 88315   http://steamcommunity.com/app/772540/reviews/?...
# ...                                                   ...
# 120439  http://steamcommunity.com/app/745400/reviews/?...
# 120440  http://steamcommunity.com/app/773640/reviews/?...
# 120441  http://steamcommunity.com/app/733530/reviews/?...
# 120442  http://steamcommunity.com/app/610660/reviews/?...
# 120443  http://steamcommunity.com/app/658870/reviews/?...
#
#                                                     specs         price  \
# 88310                                     [Single-player]          4.99
# 88311   [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 88312   [Single-player, Multi-player, Online Multi-Pla...  Free to Play
# 88313                                     [Single-player]          0.99
# 88315                 [Single-player, Steam Achievements]          3.99
# ...                                                   ...           ...
# 120439   [Single-player, Steam Achievements, Steam Cloud]          1.99
# 120440                [Single-player, Steam Achievements]          1.99
# 120441  [Single-player, Steam Achievements, Steam Clou...          4.99
# 120442  [Single-player, Steam Achievements, Steam Trad...          1.99
# 120443   [Single-player, Steam Achievements, Steam Cloud]          4.99
#
#         early_access        id                 developer
# 88310            0.0  761140.0                 Kotoshiro
# 88311            0.0  643980.0          Secret Level SRL
# 88312            0.0  670290.0              Poolians.com
# 88313            0.0  767400.0                      彼岸领域
# 88315            0.0  772540.0       Trickjump Games Ltd
# ...              ...       ...                       ...
# 120439           0.0  745400.0           Bidoniera Games
# 120440           0.0  773640.0        Nikita "Ghost_RUS"
# 120441           0.0  733530.0                    Sacada
# 120442           0.0  610660.0  Laush Dmitriy Sergeevich
# 120443           0.0  658870.0             xropi,stev3ns
#
# [22529 rows x 13 columns]

# %% [markdown]
# Se eliminan las columnas que no son necesarias

# %%
dataset.drop(['title',	'url',	'tags', 'specs', 'early_access', 'reviews_url'], axis=1, inplace=True)

# %%
dataset
# Out:
#                                    publisher  \
# 88384                                   None
# 88385                               2K Games
# 88386                                   None
# 88387                               2K Games
# 88388   Square Enix, Feral Interactive (Mac)
# ...                                      ...
# 120440                       Ghost_RUS Games
# 120441                                Sacada
# 120442                          Laush Studio
# 120443                              SIXNAILS
# 120444                                  None
#
#                                        genres                     app_name  \
# 88384                                    None                         None
# 88385                              [Strategy]  Railroad Tycoon II Platinum
# 88386                         [Casual, Indie]               RIP - Trilogy™
# 88387                              [Strategy]  X-COM: Terror From the Deep
# 88388                     [Action, Adventure]     Tomb Raider: Anniversary
# ...                                       ...                          ...
# 120440  [Casual, Indie, Simulation, Strategy]               Colony On Mars
# 120441              [Casual, Indie, Strategy]     LOGistICAL: South Africa
# 120442            [Indie, Racing, Simulation]                Russian Roads
# 120443                        [Casual, Indie]          EXIT 2 - Directions
# 120444                                   None                  Maze Run VR
#
#        release_date  price        id                                 developer
# 88384          None  19.99       NaN                                      None
# 88385    1998-10-31   4.99    7620.0                                    PopTop
# 88386    2007-06-01   4.99    2540.0                            Elephant Games
# 88387    1995-04-01   4.99    7650.0                  MicroProse Software, Inc
# 88388    2007-06-05   8.99    8000.0  Crystal Dynamics,Feral Interactive (Mac)
# ...             ...    ...       ...                                       ...
# 120440   2018-01-04   1.99  773640.0                        Nikita "Ghost_RUS"
# 120441   2018-01-04   4.99  733530.0                                    Sacada
# 120442   2018-01-04   1.99  610660.0                  Laush Dmitriy Sergeevich
# 120443   2017-09-02   4.99  658870.0                             xropi,stev3ns
# 120444         None   4.99  681550.0                                      None
#
# [32060 rows x 7 columns]

# %% [markdown]
# Eliminamos los nulos

# %%
dataset = dataset.dropna()

# %%
dataset
# Out:
#                   publisher  \
# 88310             Kotoshiro
# 88311      Making Fun, Inc.
# 88312          Poolians.com
# 88313                  彼岸领域
# 88315   Trickjump Games Ltd
# ...                     ...
# 120439      Bidoniera Games
# 120440      Ghost_RUS Games
# 120441               Sacada
# 120442         Laush Studio
# 120443             SIXNAILS
#
#                                                    genres  \
# 88310       [Action, Casual, Indie, Simulation, Strategy]
# 88311                [Free to Play, Indie, RPG, Strategy]
# 88312   [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                         [Action, Adventure, Casual]
# 88315                     [Action, Adventure, Simulation]
# ...                                                   ...
# 120439                 [Action, Adventure, Casual, Indie]
# 120440              [Casual, Indie, Simulation, Strategy]
# 120441                          [Casual, Indie, Strategy]
# 120442                        [Indie, Racing, Simulation]
# 120443                                    [Casual, Indie]
#
#                         app_name release_date         price        id  \
# 88310        Lost Summoner Kitty   2018-01-04          4.99  761140.0
# 88311                  Ironbound   2018-01-04  Free To Play  643980.0
# 88312    Real Pool 3D - Poolians   2017-07-24  Free to Play  670290.0
# 88313                    弹炸人2222   2017-12-07          0.99  767400.0
# 88315      Battle Royale Trainer   2018-01-04          3.99  772540.0
# ...                          ...          ...           ...       ...
# 120439              Kebab it Up!   2018-01-04          1.99  745400.0
# 120440            Colony On Mars   2018-01-04          1.99  773640.0
# 120441  LOGistICAL: South Africa   2018-01-04          4.99  733530.0
# 120442             Russian Roads   2018-01-04          1.99  610660.0
# 120443       EXIT 2 - Directions   2017-09-02          4.99  658870.0
#
#                        developer
# 88310                  Kotoshiro
# 88311           Secret Level SRL
# 88312               Poolians.com
# 88313                       彼岸领域
# 88315        Trickjump Games Ltd
# ...                          ...
# 120439           Bidoniera Games
# 120440        Nikita "Ghost_RUS"
# 120441                    Sacada
# 120442  Laush Dmitriy Sergeevich
# 120443             xropi,stev3ns
#
# [22529 rows x 7 columns]

# %%
dataset.rename(columns={'id': 'item_id'}, inplace=True)

# %% [markdown]
# Convierte todos los valores de tipo cadena a 0 en la columna especificada

# %%
columna_a_convertir = 'price'

dataset.loc[dataset[columna_a_convertir].apply(lambda x: isinstance(x, str)), columna_a_convertir] = 0

# %%
dataset.to_parquet('output.parquet', index=False)

# %% [markdown]
# Genero un CSV desde el Dataframe

# %%
dataset.to_csv('output.csv', index=False)

# %% [markdown]
# Leo el JSON australian_user_items

# %%
data_list = []

# %%
#Ruta del archivo JSON
file_path = 'australian_users_items.json'

#Abrir el archivo y procesar cada línea
with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        try:
            # Usar ast.literal_eval para convertir la línea en un diccionario
            json_data = ast.literal_eval(line)
            data_list.append(json_data)
        except ValueError as e:
            print(f"Error en la línea: {line}")
            continue

#Crear un DataFrame a partir de la lista de diccionarios
data_it = pd.DataFrame(data_list)

# %%
data_it
# Out:
#           item_id                  item_name  playtime_forever  \
# 0            10.0             Counter-Strike               6.0
# 1            20.0      Team Fortress Classic               0.0
# 2            30.0              Day of Defeat               7.0
# 3            40.0         Deathmatch Classic               0.0
# 4            50.0  Half-Life: Opposing Force               0.0
# ...           ...                        ...               ...
# 7411032  292030.0   The Witcher 3: Wild Hunt            2331.0
# 7411033  377160.0                  Fallout 4           18839.0
# 7411034  299360.0               Block N Load             234.0
# 7411035   50130.0                   Mafia II             905.0
# 7411036  105600.0                   Terraria             201.0
#
#          playtime_2weeks            user_id  items_count           steam_id  \
# 0                    0.0  76561197970982479          277  76561197970982479
# 1                    0.0  76561197970982479          277  76561197970982479
# 2                    0.0  76561197970982479          277  76561197970982479
# 3                    0.0  76561197970982479          277  76561197970982479
# 4                    0.0  76561197970982479          277  76561197970982479
# ...                  ...                ...          ...                ...
# 7411032              0.0  76561198058580105          145  76561198058580105
# 7411033           1143.0  76561198058580105          145  76561198058580105
# 7411034              0.0  76561198058580105          145  76561198058580105
# 7411035              0.0  76561198058580105          145  76561198058580105
# 7411036              0.0            Pheress           35  76561198083186121
#
#                                                   user_url  \
# 0        http://steamcommunity.com/profiles/76561197970...
# 1        http://steamcommunity.com/profiles/76561197970...
# 2        http://steamcommunity.com/profiles/76561197970...
# 3        http://steamcommunity.com/profiles/76561197970...
# 4        http://steamcommunity.com/profiles/76561197970...
# ...                                                    ...
# 7411032  http://steamcommunity.com/profiles/76561198058...
# 7411033  http://steamcommunity.com/profiles/76561198058...
# 7411034  http://steamcommunity.com/profiles/76561198058...
# 7411035  http://steamcommunity.com/profiles/76561198058...
# 7411036               http://steamcommunity.com/id/Pheress
#
#                                                      items
# 0        {'item_id': '10', 'item_name': 'Counter-Strike...
# 1        {'item_id': '20', 'item_name': 'Team Fortress ...
# 2        {'item_id': '30', 'item_name': 'Day of Defeat'...
# 3        {'item_id': '40', 'item_name': 'Deathmatch Cla...
# 4        {'item_id': '50', 'item_name': 'Half-Life: Opp...
# ...                                                    ...
# 7411032  {'item_id': '292030', 'item_name': 'The Witche...
# 7411033  {'item_id': '377160', 'item_name': 'Fallout 4'...
# 7411034  {'item_id': '299360', 'item_name': 'Block N Lo...
# 7411035  {'item_id': '50130', 'item_name': 'Mafia II', ...
# 7411036  {'item_id': '105600', 'item_name': 'Terraria',...
#
# [7411037 rows x 9 columns]

# %% [markdown]
# Se desanidan los datos de la columna ['items']

# %%
data_it1 = data_it.explode(['items'])
data_it2 = pd.json_normalize(data_it1['items']).set_index(data_it1['items'].index)
data_it3= pd.concat([data_it2, data_it1], axis=1)

# %%
data_it3
# Out:
#           item_id                  item_name  playtime_forever  \
# 0            10.0             Counter-Strike               6.0
# 1            20.0      Team Fortress Classic               0.0
# 2            30.0              Day of Defeat               7.0
# 3            40.0         Deathmatch Classic               0.0
# 4            50.0  Half-Life: Opposing Force               0.0
# ...           ...                        ...               ...
# 7411032  292030.0   The Witcher 3: Wild Hunt            2331.0
# 7411033  377160.0                  Fallout 4           18839.0
# 7411034  299360.0               Block N Load             234.0
# 7411035   50130.0                   Mafia II             905.0
# 7411036  105600.0                   Terraria             201.0
#
#          playtime_2weeks            user_id  items_count           steam_id  \
# 0                    0.0  76561197970982479          277  76561197970982479
# 1                    0.0  76561197970982479          277  76561197970982479
# 2                    0.0  76561197970982479          277  76561197970982479
# 3                    0.0  76561197970982479          277  76561197970982479
# 4                    0.0  76561197970982479          277  76561197970982479
# ...                  ...                ...          ...                ...
# 7411032              0.0  76561198058580105          145  76561198058580105
# 7411033           1143.0  76561198058580105          145  76561198058580105
# 7411034              0.0  76561198058580105          145  76561198058580105
# 7411035              0.0  76561198058580105          145  76561198058580105
# 7411036              0.0            Pheress           35  76561198083186121
#
#                                                   user_url  \
# 0        http://steamcommunity.com/profiles/76561197970...
# 1        http://steamcommunity.com/profiles/76561197970...
# 2        http://steamcommunity.com/profiles/76561197970...
# 3        http://steamcommunity.com/profiles/76561197970...
# 4        http://steamcommunity.com/profiles/76561197970...
# ...                                                    ...
# 7411032  http://steamcommunity.com/profiles/76561198058...
# 7411033  http://steamcommunity.com/profiles/76561198058...
# 7411034  http://steamcommunity.com/profiles/76561198058...
# 7411035  http://steamcommunity.com/profiles/76561198058...
# 7411036               http://steamcommunity.com/id/Pheress
#
#                                                      items
# 0        {'item_id': '10', 'item_name': 'Counter-Strike...
# 1        {'item_id': '20', 'item_name': 'Team Fortress ...
# 2        {'item_id': '30', 'item_name': 'Day of Defeat'...
# 3        {'item_id': '40', 'item_name': 'Deathmatch Cla...
# 4        {'item_id': '50', 'item_name': 'Half-Life: Opp...
# ...                                                    ...
# 7411032  {'item_id': '292030', 'item_name': 'The Witche...
# 7411033  {'item_id': '377160', 'item_name': 'Fallout 4'...
# 7411034  {'item_id': '299360', 'item_name': 'Block N Lo...
# 7411035  {'item_id': '50130', 'item_name': 'Mafia II', ...
# 7411036  {'item_id': '105600', 'item_name': 'Terraria',...
#
# [7411037 rows x 9 columns]

# %% [markdown]
# Se eliminan las columnas que no se consideran relevantes para el posterior analisis

# %%
data_it3.drop(['items_count','user_url','item_name','steam_id'], axis=1, inplace=True)

# %% [markdown]
# Se eliminan los datos nulos por columnas

# %%
data_it3 = data_it3.dropna(subset=['item_id'])
data_it3 = data_it3.dropna(subset=['playtime_forever'])

# %% [markdown]
# Se eliminan 2 columnas adicionales

# %%
data_it3.drop(['items','playtime_2weeks'], axis=1, inplace=True)

# %% [markdown]
# Se define el dataframe solo para aquellos juegos donde tuvieron un tiempo jugado (condicion)

# %%
data_it3 = data_it3[data_it3['playtime_forever'] != 0]

# %% [markdown]
# Se conservan las 3 columnas para el analisis

# %%
data_it3 = data_it3[['user_id','item_id','playtime_forever']]

# %% [markdown]
# Creo el archivo en formato parquet para reduccion de peso

# %%
data_it3.to_parquet('user_items.parquet', index= False)

# %% [markdown]
# Se exporta la tabla como archivo separa por comas de nombre 'user_items'

# %%
data_it3.to_csv('user_items.csv', index=False)

# %% [markdown]
# Leo el JSON australian_user_items

# %%
data_list1 = []

# %%
#Ruta del archivo JSON
file_path = 'australian_user_reviews.json'

#Abrir el archivo y procesar cada línea
with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        try:
            # Usar ast.literal_eval para convertir la línea en un diccionario
            json_data = ast.literal_eval(line)
            data_list1.append(json_data)
        except ValueError as e:
            print(f"Error en la línea: {line}")
            continue

#Crear un DataFrame a partir de la lista de diccionarios
data_it = pd.DataFrame(data_list1)

# %%
data_it
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 25794  76561198306599751  http://steamcommunity.com/profiles/76561198306...
# 25795           Ghoustik              http://steamcommunity.com/id/Ghoustik
# 25796  76561198310819422  http://steamcommunity.com/profiles/76561198310...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# 0      [{'funny': '', 'posted': 'Posted November 5, 2...
# 1      [{'funny': '', 'posted': 'Posted June 24, 2014...
# 2      [{'funny': '', 'posted': 'Posted February 3.',...
# 3      [{'funny': '', 'posted': 'Posted October 14, 2...
# 4      [{'funny': '3 people found this review funny',...
# ...                                                  ...
# 25794  [{'funny': '', 'posted': 'Posted May 31.', 'la...
# 25795  [{'funny': '', 'posted': 'Posted June 17.', 'l...
# 25796  [{'funny': '1 person found this review funny',...
# 25797  [{'funny': '', 'posted': 'Posted July 21.', 'l...
# 25798  [{'funny': '1 person found this review funny',...
#
# [25799 rows x 3 columns]

# %% [markdown]
# Se desanidan los datos de la columna ['reviews']

# %%
data_it1 = data_it.explode(['reviews'])
data_it2 = pd.json_normalize(data_it1['reviews']).set_index(data_it1['reviews'].index)
data_it3= pd.concat([data_it2, data_it1], axis=1)

# %%
data_it3
# Out:
#                                   funny                     posted  \
# 0                                         Posted November 5, 2011.
# 0                                            Posted July 15, 2011.
# 0                                           Posted April 21, 2011.
# 1                                            Posted June 24, 2014.
# 1                                        Posted September 8, 2013.
# ...                                 ...                        ...
# 25797                                              Posted July 10.
# 25797                                               Posted July 8.
# 25798  1 person found this review funny             Posted July 3.
# 25798                                              Posted July 20.
# 25798                                               Posted July 2.
#
#       last_edited item_id                                          helpful  \
# 0                    1250                                   No ratings yet
# 0                   22200                                   No ratings yet
# 0                   43110                                   No ratings yet
# 1                  251610  15 of 20 people (75%) found this review helpful
# 1                  227300     0 of 1 people (0%) found this review helpful
# ...           ...     ...                                              ...
# 25797                  70                                   No ratings yet
# 25797              362890                                   No ratings yet
# 25798              273110    1 of 2 people (50%) found this review helpful
# 25798                 730                                   No ratings yet
# 25798                 440                                   No ratings yet
#
#       recommend                                             review  \
# 0          True  Simple yet with great replayability. In my opi...
# 0          True               It's unique and worth a playthrough.
# 0          True  Great atmosphere. The gunplay can be a bit chu...
# 1          True  I know what you think when you see this title ...
# 1          True  For a simple (it's actually not all that simpl...
# ...         ...                                                ...
# 25797      True  a must have classic from steam definitely wort...
# 25797      True  this game is a perfect remake of the original ...
# 25798      True  had so much fun plaing this and collecting res...
# 25798      True                                                 :D
# 25798      True                                     so much fun :D
#
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 1                js41637               http://steamcommunity.com/id/js41637
# ...                  ...                                                ...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# 0      {'funny': '', 'posted': 'Posted November 5, 20...
# 0      {'funny': '', 'posted': 'Posted July 15, 2011....
# 0      {'funny': '', 'posted': 'Posted April 21, 2011...
# 1      {'funny': '', 'posted': 'Posted June 24, 2014....
# 1      {'funny': '', 'posted': 'Posted September 8, 2...
# ...                                                  ...
# 25797  {'funny': '', 'posted': 'Posted July 10.', 'la...
# 25797  {'funny': '', 'posted': 'Posted July 8.', 'las...
# 25798  {'funny': '1 person found this review funny', ...
# 25798  {'funny': '', 'posted': 'Posted July 20.', 'la...
# 25798  {'funny': '', 'posted': 'Posted July 2.', 'las...
#
# [59333 rows x 10 columns]

# %% [markdown]
# Se eliminan las columnas que no se consideran relevantes para el posterior analisis

# %%
data_it3.drop(['funny','last_edited','helpful','user_url'], axis=1, inplace=True)

# %%
data_it3
# Out:
#                           posted item_id recommend  \
# 0       Posted November 5, 2011.    1250      True
# 0          Posted July 15, 2011.   22200      True
# 0         Posted April 21, 2011.   43110      True
# 1          Posted June 24, 2014.  251610      True
# 1      Posted September 8, 2013.  227300      True
# ...                          ...     ...       ...
# 25797            Posted July 10.      70      True
# 25797             Posted July 8.  362890      True
# 25798             Posted July 3.  273110      True
# 25798            Posted July 20.     730      True
# 25798             Posted July 2.     440      True
#
#                                                   review            user_id  \
# 0      Simple yet with great replayability. In my opi...  76561197970982479
# 0                   It's unique and worth a playthrough.  76561197970982479
# 0      Great atmosphere. The gunplay can be a bit chu...  76561197970982479
# 1      I know what you think when you see this title ...            js41637
# 1      For a simple (it's actually not all that simpl...            js41637
# ...                                                  ...                ...
# 25797  a must have classic from steam definitely wort...  76561198312638244
# 25797  this game is a perfect remake of the original ...  76561198312638244
# 25798  had so much fun plaing this and collecting res...        LydiaMorley
# 25798                                                 :D        LydiaMorley
# 25798                                     so much fun :D        LydiaMorley
#
#                                                  reviews
# 0      {'funny': '', 'posted': 'Posted November 5, 20...
# 0      {'funny': '', 'posted': 'Posted July 15, 2011....
# 0      {'funny': '', 'posted': 'Posted April 21, 2011...
# 1      {'funny': '', 'posted': 'Posted June 24, 2014....
# 1      {'funny': '', 'posted': 'Posted September 8, 2...
# ...                                                  ...
# 25797  {'funny': '', 'posted': 'Posted July 10.', 'la...
# 25797  {'funny': '', 'posted': 'Posted July 8.', 'las...
# 25798  {'funny': '1 person found this review funny', ...
# 25798  {'funny': '', 'posted': 'Posted July 20.', 'la...
# 25798  {'funny': '', 'posted': 'Posted July 2.', 'las...
#
# [59333 rows x 6 columns]

# %% [markdown]
# Se eliminan los datos nulos por columnas

# %%
#se eliminan los datos nulos por columnas
data_it3 = data_it3.dropna(subset=['posted'])
data_it3 = data_it3.dropna(subset=['item_id'])

# %%
data_it3
# Out:
#                           posted item_id recommend  \
# 0       Posted November 5, 2011.    1250      True
# 0          Posted July 15, 2011.   22200      True
# 0         Posted April 21, 2011.   43110      True
# 1          Posted June 24, 2014.  251610      True
# 1      Posted September 8, 2013.  227300      True
# ...                          ...     ...       ...
# 25797            Posted July 10.      70      True
# 25797             Posted July 8.  362890      True
# 25798             Posted July 3.  273110      True
# 25798            Posted July 20.     730      True
# 25798             Posted July 2.     440      True
#
#                                                   review            user_id  \
# 0      Simple yet with great replayability. In my opi...  76561197970982479
# 0                   It's unique and worth a playthrough.  76561197970982479
# 0      Great atmosphere. The gunplay can be a bit chu...  76561197970982479
# 1      I know what you think when you see this title ...            js41637
# 1      For a simple (it's actually not all that simpl...            js41637
# ...                                                  ...                ...
# 25797  a must have classic from steam definitely wort...  76561198312638244
# 25797  this game is a perfect remake of the original ...  76561198312638244
# 25798  had so much fun plaing this and collecting res...        LydiaMorley
# 25798                                                 :D        LydiaMorley
# 25798                                     so much fun :D        LydiaMorley
#
#                                                  reviews
# 0      {'funny': '', 'posted': 'Posted November 5, 20...
# 0      {'funny': '', 'posted': 'Posted July 15, 2011....
# 0      {'funny': '', 'posted': 'Posted April 21, 2011...
# 1      {'funny': '', 'posted': 'Posted June 24, 2014....
# 1      {'funny': '', 'posted': 'Posted September 8, 2...
# ...                                                  ...
# 25797  {'funny': '', 'posted': 'Posted July 10.', 'la...
# 25797  {'funny': '', 'posted': 'Posted July 8.', 'las...
# 25798  {'funny': '1 person found this review funny', ...
# 25798  {'funny': '', 'posted': 'Posted July 20.', 'la...
# 25798  {'funny': '', 'posted': 'Posted July 2.', 'las...
#
# [59305 rows x 6 columns]

# %% [markdown]
# Se eliminan 2 columnas adicionales

# %%
data_it3.drop(['reviews'], axis=1, inplace=True)

# %% [markdown]
# Se define el dataframe solo para aquellos juegos donde tuvieron un tiempo jugado (condicion)

# %%
#se define el dataframe solo para aquellos juegos donde tuvieron un tiempo jugado (condicion)
data_it3 = data_it3[data_it3['item_id'] != 0]

# %%
data_it3
# Out:
#                           posted item_id recommend  \
# 0       Posted November 5, 2011.    1250      True
# 0          Posted July 15, 2011.   22200      True
# 0         Posted April 21, 2011.   43110      True
# 1          Posted June 24, 2014.  251610      True
# 1      Posted September 8, 2013.  227300      True
# ...                          ...     ...       ...
# 25797            Posted July 10.      70      True
# 25797             Posted July 8.  362890      True
# 25798             Posted July 3.  273110      True
# 25798            Posted July 20.     730      True
# 25798             Posted July 2.     440      True
#
#                                                   review            user_id
# 0      Simple yet with great replayability. In my opi...  76561197970982479
# 0                   It's unique and worth a playthrough.  76561197970982479
# 0      Great atmosphere. The gunplay can be a bit chu...  76561197970982479
# 1      I know what you think when you see this title ...            js41637
# 1      For a simple (it's actually not all that simpl...            js41637
# ...                                                  ...                ...
# 25797  a must have classic from steam definitely wort...  76561198312638244
# 25797  this game is a perfect remake of the original ...  76561198312638244
# 25798  had so much fun plaing this and collecting res...        LydiaMorley
# 25798                                                 :D        LydiaMorley
# 25798                                     so much fun :D        LydiaMorley
#
# [59305 rows x 5 columns]

# %% [markdown]
# Se eliminan los duplicados y valores nulos en caso de haber

# %%
data_it3 = data_it3.drop_duplicates()
data_it3 = data_it3.dropna()

# %%
data_it3.to_parquet('user_reviews.parquet', index=False)

# %% [markdown]
# Se exporta la tabla como archivo separa por comas de nombre 'user_Reviews'

# %%
#se exporta la tabla como archivo separa por comas de nombre 'user_items'
data_it3.to_csv('user_reviews.csv', index=False)

# %% [markdown]
# Se crea el analisis de sentimiento sobre la columna review

# %%
from textblob import TextBlob

# %%
def analyze_sentiment(review):
    analysis = TextBlob(str(review))
    # Asigna un valor según el análisis de sentimiento
    if analysis.sentiment.polarity > 0.1: 
        return 2  # Positivo
    elif analysis.sentiment.polarity < -0.1:
        return 0  # Malo
    else:
        return 1  # Neutral

# %% [markdown]
# Se agrega la columna Sentiment_analysis

# %%
data_it3['Sentiment_analysis'] = data_it3['review'].apply(analyze_sentiment)

# %%
data_it3
# Out:
#                           posted item_id recommend  \
# 0       Posted November 5, 2011.    1250      True
# 0          Posted July 15, 2011.   22200      True
# 0         Posted April 21, 2011.   43110      True
# 1          Posted June 24, 2014.  251610      True
# 1      Posted September 8, 2013.  227300      True
# ...                          ...     ...       ...
# 25797            Posted July 10.      70      True
# 25797             Posted July 8.  362890      True
# 25798             Posted July 3.  273110      True
# 25798            Posted July 20.     730      True
# 25798             Posted July 2.     440      True
#
#                                                   review            user_id  \
# 0      Simple yet with great replayability. In my opi...  76561197970982479
# 0                   It's unique and worth a playthrough.  76561197970982479
# 0      Great atmosphere. The gunplay can be a bit chu...  76561197970982479
# 1      I know what you think when you see this title ...            js41637
# 1      For a simple (it's actually not all that simpl...            js41637
# ...                                                  ...                ...
# 25797  a must have classic from steam definitely wort...  76561198312638244
# 25797  this game is a perfect remake of the original ...  76561198312638244
# 25798  had so much fun plaing this and collecting res...        LydiaMorley
# 25798                                                 :D        LydiaMorley
# 25798                                     so much fun :D        LydiaMorley
#
#        Sentiment_analysis
# 0                       2
# 0                       2
# 0                       1
# 1                       2
# 1                       1
# ...                   ...
# 25797                   2
# 25797                   2
# 25798                   1
# 25798                   2
# 25798                   2
#
# [58431 rows x 6 columns]

# %%
data_it3.to_parquet('user_reviews.parquet', index=False)

# %% [markdown]
# Se vuelve a crear el CSV

# %%
data_it3.to_csv('user_reviews.csv', index=False)

# %% [markdown]
# Volvemos a llamar a los CSV para la creacion de una tabla unica con un JOIN

# %%
dfgames = pd.read_csv('output.csv')
dfitems = pd.read_csv('user_items.csv')
dfreviews = pd.read_csv('user_reviews.csv')

# %% [markdown]
# Volvemos a chequear si hay datos faltantes

# %%
dfgames = dfgames.dropna()

# %%
dfitems = dfitems.dropna()

# %%
dfreviews = dfreviews.dropna()

# %% [markdown]
# Uni los Datasets de Users

# %%
df_merge = pd.merge(dfitems,dfreviews, how="inner")

# %%
df_merge
# Out:
#                  user_id item_id  playtime_forever                     posted  \
# 0      76561197970982479   22200             271.0      Posted July 15, 2011.
# 1      76561197970982479    1250           10006.0   Posted November 5, 2011.
# 2      76561197970982479   43110             834.0     Posted April 21, 2011.
# 3                js41637  227300             551.0  Posted September 8, 2013.
# 4                js41637  239030             349.0  Posted November 29, 2013.
# ...                  ...     ...               ...                        ...
# 44799           Ghoustik     730            3969.0            Posted June 17.
# 44800  76561198312638244      70            1010.0            Posted July 10.
# 44801  76561198312638244     130             221.0            Posted July 10.
# 44802  76561198312638244  233270             533.0            Posted July 21.
# 44803  76561198312638244  362890            2184.0             Posted July 8.
#
#        recommend                                             review  \
# 0           True               It's unique and worth a playthrough.
# 1           True  Simple yet with great replayability. In my opi...
# 2           True  Great atmosphere. The gunplay can be a bit chu...
# 3           True  For a simple (it's actually not all that simpl...
# 4           True  Very fun little game to play when your bored o...
# ...          ...                                                ...
# 44799       True  Gra naprawdę fajna.Ale jest kilka rzeczy do kt...
# 44800       True  a must have classic from steam definitely wort...
# 44801       True  if you liked Half life i would really recommen...
# 44802       True  this is a very fun and nice 80s themed shooter...
# 44803       True  this game is a perfect remake of the original ...
#
#        Sentiment_analysis
# 0                       2
# 1                       2
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 44799                   1
# 44800                   2
# 44801                   2
# 44802                   2
# 44803                   2
#
# [44804 rows x 7 columns]

# %% [markdown]
# Renombro la columna id de output por item_id para que se pueda relacionar

# %%
dfgames.rename(columns={'id': 'item_id'}, inplace=True)

# %%
dfgames
# Out:
#                                   publisher  \
# 0                                  2K Games
# 1                                  2K Games
# 2      Square Enix, Feral Interactive (Mac)
# 3                                    Capcom
# 4                            Telltale Games
# ...                                     ...
# 22762                       Bidoniera Games
# 22763                       Ghost_RUS Games
# 22764                                Sacada
# 22765                          Laush Studio
# 22766                              SIXNAILS
#
#                                       genres  \
# 0                                 [Strategy]
# 1                                 [Strategy]
# 2                        [Action, Adventure]
# 3                                   [Action]
# 4                        [Action, Adventure]
# ...                                      ...
# 22762     [Action, Adventure, Casual, Indie]
# 22763  [Casual, Indie, Simulation, Strategy]
# 22764              [Casual, Indie, Strategy]
# 22765            [Indie, Racing, Simulation]
# 22766                        [Casual, Indie]
#
#                                app_name release_date  price   item_id  \
# 0           Railroad Tycoon II Platinum   1998-10-31   4.99    7620.0
# 1           X-COM: Terror From the Deep   1995-04-01   4.99    7650.0
# 2              Tomb Raider: Anniversary   2007-06-05   8.99    8000.0
# 3      Devil May Cry® 3 Special Edition   2006-05-23  19.99    6550.0
# 4          Sam & Max 101: Culture Shock   2006-10-17  19.99    8200.0
# ...                                 ...          ...    ...       ...
# 22762                      Kebab it Up!   2018-01-04   1.99  745400.0
# 22763                    Colony On Mars   2018-01-04   1.99  773640.0
# 22764          LOGistICAL: South Africa   2018-01-04   4.99  733530.0
# 22765                     Russian Roads   2018-01-04   1.99  610660.0
# 22766               EXIT 2 - Directions   2017-09-02   4.99  658870.0
#
#                                       developer
# 0                                        PopTop
# 1                      MicroProse Software, Inc
# 2      Crystal Dynamics,Feral Interactive (Mac)
# 3                              CAPCOM Co., Ltd.
# 4                                Telltale Games
# ...                                         ...
# 22762                           Bidoniera Games
# 22763                        Nikita "Ghost_RUS"
# 22764                                    Sacada
# 22765                  Laush Dmitriy Sergeevich
# 22766                             xropi,stev3ns
#
# [22767 rows x 7 columns]

# %%
df_merge = pd.merge(dfgames,df_merge, how="inner")

# %%
df_merge
# Out:
#                                   publisher                   genres  \
# 0      Square Enix, Feral Interactive (Mac)  ['Action', 'Adventure']
# 1                                    Capcom               ['Action']
# 2                                    Capcom               ['Action']
# 3                                    Capcom               ['Action']
# 4                                    Capcom               ['Action']
# ...                                     ...                      ...
# 52474                                 Valve               ['Action']
# 52475                                 Valve               ['Action']
# 52476                                 Valve               ['Action']
# 52477                                 Valve               ['Action']
# 52478                                 Valve               ['Action']
#
#                                app_name release_date  price  item_id  \
# 0              Tomb Raider: Anniversary   2007-06-05   8.99   8000.0
# 1      Devil May Cry® 3 Special Edition   2006-05-23  19.99   6550.0
# 2      Devil May Cry® 3 Special Edition   2006-05-23  19.99   6550.0
# 3      Devil May Cry® 3 Special Edition   2006-05-23  19.99   6550.0
# 4      Devil May Cry® 3 Special Edition   2006-05-23  19.99   6550.0
# ...                                 ...          ...    ...      ...
# 52474    Counter-Strike: Condition Zero   2004-03-01   9.99     80.0
# 52475    Counter-Strike: Condition Zero   2004-03-01   9.99     80.0
# 52476    Counter-Strike: Condition Zero   2004-03-01   9.99     80.0
# 52477    Counter-Strike: Condition Zero   2004-03-01   9.99     80.0
# 52478    Counter-Strike: Condition Zero   2004-03-01   9.99     80.0
#
#                                       developer            user_id  \
# 0      Crystal Dynamics,Feral Interactive (Mac)  76561198052998873
# 1                              CAPCOM Co., Ltd.        ryanflyin13
# 2                              CAPCOM Co., Ltd.        ryanflyin13
# 3                              CAPCOM Co., Ltd.      SambaWarKiddo
# 4                              CAPCOM Co., Ltd.      SambaWarKiddo
# ...                                         ...                ...
# 52474                                     Valve             virex4
# 52475                                     Valve      KILLERamateur
# 52476                                     Valve  76561198015050660
# 52477                                     Valve  76561198023508728
# 52478                                     Valve           green290
#
#        playtime_forever                     posted  recommend  \
# 0                 378.0  Posted December 11, 2015.       True
# 1                2872.0             Posted June 4.       True
# 2                2872.0             Posted June 4.       True
# 3                  47.0       Posted May 31, 2014.       True
# 4                  47.0       Posted May 31, 2014.       True
# ...                 ...                        ...        ...
# 52474           26740.0  Posted December 28, 2011.       True
# 52475            3721.0      Posted March 9, 2014.       True
# 52476            2416.0  Posted December 23, 2014.      False
# 52477              15.0   Posted October 26, 2014.      False
# 52478             442.0    Posted January 5, 2015.       True
#
#                                                   review  Sentiment_analysis
# 0      One of the best games of all time, I have been...                   2
# 1      This game made a huge impact on my life when i...                   1
# 2      This game made a huge impact on my life when i...                   1
# 3      Fantastic game by absolutely all means, and if...                   2
# 4      Fantastic game by absolutely all means, and if...                   2
# ...                                                  ...                 ...
# 52474                                                 :D                   2
# 52475  cool. Same as the first one but the maps and w...                   2
# 52476  作為第一個在steam入手的遊戲，老實說當初是為了1.6來順便帶回來，由於當時網路不太穩的關...                   1
# 52477                                      i caused 9/11                   1
# 52478  This game was suprisingly my first FPS game.11...                   2
#
# [52479 rows x 13 columns]

# %% [markdown]
# Se crea el CSV y se ubica en la carpeta data asi los proximos CSV se alojen en el mismo lugar

# %%
df_merge.to_parquet('df_merge.parquet', index=False)

# %%
df_merge = pd.read_csv('data/df_merge.csv', encoding='utf-8')

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36578 entries, 0 to 36577
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   publisher           36578 non-null  object
#  1   genres              36578 non-null  object
#  2   app_name            36578 non-null  object
#  3   release_date        36578 non-null  object
#  4   price               36578 non-null  object
#  5   item_id             36578 non-null  float64
#  6   developer           36578 non-null  object
#  7   user_id             36578 non-null  object
#  8   playtime_forever    36578 non-null  float64
#  9   posted              36578 non-null  object
#  10  recommend           36578 non-null  bool
#  11  review              36578 non-null  object
#  12  Sentiment_analysis  36578 non-null  int64
# dtypes: bool(1), float64(2), int64(1), object(9)
# memory usage: 3.4+ MB

# %% [markdown]
# Se cambia el tipo de dato de Free to play a 0 para poder hacer el analisis

# %%
df_merge['price'] = df_merge['price'].replace('Free to Play', 0)

# %% [markdown]
# Convertir la columna 'price' a tipo numérico y reemplazar NaN con ceros

# %%
# Convertir la columna 'price' a tipo numérico y reemplazar NaN con ceros
df_merge['price'] = pd.to_numeric(df_merge['price'], errors='coerce').fillna(0)

# Imprimir los valores no numéricos en la columna 'price' después de la conversión
print("Valores no numéricos en la columna 'price' después de la conversión:")
print(df_merge.loc[df_merge['price'].isnull(),'price'])
# Out:
# Valores no numéricos en la columna 'price' después de la conversión:
# Series([], Name: price, dtype: float64)

# %% [markdown]
# Se configura la columna release_date a un valor de años

# %%
# Supongamos que 'release_date' es la columna que contiene las fechas
df_merge['release_date'] = pd.to_datetime(df_merge['release_date'], errors='coerce')

# Asegúrate de que no haya valores nulos en la columna 'release_date'
print(df_merge['release_date'].isnull().sum())

# Crea la columna 'Años' extrayendo el año después de la conversión
df_merge['Años'] = df_merge['release_date'].dt.year

# Imprime el DataFrame para verificar los resultados
print(df_merge)
# Out:
# 186
#                                   publisher                   genres  \
# 0      Square Enix, Feral Interactive (Mac)  ['Action', 'Adventure']
# 1                                    Capcom               ['Action']
# 2                                    Capcom               ['Action']
# 3                                    Capcom               ['Action']
# 4                                    Capcom               ['Action']
# ...                                     ...                      ...
# 36573                                 Valve               ['Action']
# 36574                                 Valve               ['Action']
# 36575                                 Valve               ['Action']
# 36576                                 Valve               ['Action']
# 36577                                 Valve               ['Action']
#
#                                app_name release_date  price  item_id  \
# 0              Tomb Raider: Anniversary   2007-06-05   8.99   8000.0
# 1      Devil May Cry® 3 Special Edition   2006-05-23  19.99   6550.0
# 2      Devil May Cry® 3 Special Edition   2006-05-23  19.99   6550.0
# 3      Devil May Cry® 3 Special Edition   2006-05-23  19.99   6550.0
# 4      Devil May Cry® 3 Special Edition   2006-05-23  19.99   6550.0
# ...                                 ...          ...    ...      ...
# 36573    Counter-Strike: Condition Zero   2004-03-01   9.99     80.0
# 36574    Counter-Strike: Condition Zero   2004-03-01   9.99     80.0
# 36575    Counter-Strike: Condition Zero   2004-03-01   9.99     80.0
# 36576    Counter-Strike: Condition Zero   2004-03-01   9.99     80.0
# 36577    Counter-Strike: Condition Zero   2004-03-01   9.99     80.0
#
#                                       developer                  user_id  \
# 0      Crystal Dynamics,Feral Interactive (Mac)        76561198052998873
# 1                              CAPCOM Co., Ltd.              ryanflyin13
# 2                              CAPCOM Co., Ltd.            SambaWarKiddo
# 3                              CAPCOM Co., Ltd.        76561198104824869
# 4                              CAPCOM Co., Ltd.        76561198096849086
# ...                                         ...                      ...
# 36573                                     Valve        76561198015050660
# 36574                                     Valve        76561198023508728
# 36575                                     Valve                 green290
# 36576                                     Valve  174gamecuman700kngkakak
# 36577                                     Valve                   lachwe
#
#        playtime_forever                     posted  recommend  \
# 0                 378.0  Posted December 11, 2015.       True
# 1                2872.0             Posted June 4.       True
# 2                  47.0       Posted May 31, 2014.       True
# 3                4169.0  Posted February 22, 2014.       True
# 4                 776.0       Posted July 1, 2014.       True
# ...                 ...                        ...        ...
# 36573            2416.0  Posted December 23, 2014.      False
# 36574              15.0   Posted October 26, 2014.      False
# 36575             442.0    Posted January 5, 2015.       True
# 36576              72.0   Posted October 31, 2014.       True
# 36577              62.0        Posted May 4, 2015.       True
#
#                                                   review  Sentiment_analysis  \
# 0      One of the best games of all time, I have been...                   2
# 1      This game made a huge impact on my life when i...                   1
# 2      Fantastic game by absolutely all means, and if...                   2
# 3      虽然不支持控制器和不能全银幕的游戏，但并不会减少游戏的可玩性和热趣，你依然可以灵活的进行华丽...                   1
# 4      .Una compra recomendada para los que les gusta...                   1
# ...                                                  ...                 ...
# 36573  作為第一個在steam入手的遊戲，老實說當初是為了1.6來順便帶回來，由於當時網路不太穩的關...                   1
# 36574                                      i caused 9/11                   1
# 36575  This game was suprisingly my first FPS game.11...                   2
# 36576                                                 :v                   1
# 36577  Random enemies popping out of no where will ma...                   0
#
#          Años
# 0      2007.0
# 1      2006.0
# 2      2006.0
# 3      2006.0
# 4      2006.0
# ...       ...
# 36573  2004.0
# 36574  2004.0
# 36575  2004.0
# 36576  2004.0
# 36577  2004.0
#
# [36578 rows x 14 columns]

# %%
modelo = df_merge.head(4000)

# %%
modelo.to_parquet('modelo.parquet', index=False)

# %% [markdown]
# Se guarda el CSV final luego de todo el Preprocesamiento de los datos

# %%
df_merge.to_parquet('df_merge.parquet', index=False)
